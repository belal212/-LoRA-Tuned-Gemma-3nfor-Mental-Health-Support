# %% [markdown]
# <a href="https://colab.research.google.com/github/belal212/-LoRA-Tuned-Gemma-3nfor-Mental-Health-Support/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh
# Out:
# fatal: destination path 'unsloth' already exists and is not an empty directory.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#   frontend       up to date
#                  Colab detected, installing Studio backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [====================] 14/14  ROCm torch (final)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#                  installing prebuilt llama.cpp...
#                  existing install detected -- validating update
#   llama.cpp      prebuilt up to date and validated
#                  installed release: unslothai/llama.cpp@b8902
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
# sys.path.insert(0, "/content/unsloth/studio/backend")
from studio.backend.colab import start
start()
# Out:
# 2026-04-23 23:38:29 [info     ] 🦥 Starting Unsloth Studio...
# 2026-04-23 23:38:29 [info     ]    Loading backend...
# 2026-04-23 23:38:30 [info     ]    Starting server...
# INFO:     Started server process [38498]
# INFO:     Waiting for application startup.
# Hardware detected: CUDA -- Tesla T4
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8888 (Press CTRL+C to quit)
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Studio UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-04-23T23:38:40.397318Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="http://localhost:8888" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 12px 0 0 0; font-size: 14px; font-weight: bold;">
#             If the link doesn't work, you can scroll down to view the UI generated directly in Colab.
#         </p>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             http://localhost:8888
#         </p>
#     </div>

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-04-23T23:38:47.293723Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 1.6}
# {"timestamp": "2026-04-23T23:38:48.016840Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/gemma-4-E2B-it-GGUF/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-04-23T23:38:53.907686Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.55}
# {"timestamp": "2026-04-23T23:38:54.526512Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 9.66}
# {"timestamp": "2026-04-23T23:38:54.930475Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 5.81}
# {"timestamp": "2026-04-23T23:38:56.101488Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 16.16}
# {"timestamp": "2026-04-23T23:39:07.250403Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# ={"timestamp": "2026-04-23T23:44:17.568635Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 145.79}
# {"timestamp": "2026-04-23T23:44:19.047636Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 163.16}
# {"timestamp": "2026-04-23T23:44:19.508344Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.51}
# {"timestamp": "2026-04-23T23:44:19.882857Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.6}
# {"timestamp": "2026-04-23T23:44:20.349798Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.56}
# {"timestamp": "2026-04-23T23:44:20.536512Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-04-23T23:44:21.077946Z", "level": "info", "event": "Top GGUF models: ['unsloth/gemma-4-26B-A4B-it-GGUF', 'unsloth/gemma-4-31B-it-GGUF', 'unsloth/gemma-4-E4B-it-GGUF', 'unsloth/Qwen3.6-35B-A3B-GGUF', 'unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/gemma-4-E2B-it-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/Qwen3.5-2B-GGUF', 'unsloth/Qwen3.5-122B-A10B-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/gpt-oss-120b-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/MiniMax-M2.7-GGUF', 'unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/gemma-3-12b-it-GGUF', 'unsloth/Qwen3.6-27B-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/GLM-4.7-Flash-GGUF', 'unsloth/MiniMax-M2.5-
z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.39}
# {"timestamp": "2026-04-23T23:47:34.922627Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 3.11}
# {"timestamp": "2026-04-23T23:47:34.926596Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 4.05}
# {"timestamp": "2026-04-23T23:47:35.128761Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 8.8}
# {"timestamp": "2026-04-23T23:47:35.130920Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 10.67}
# {"timestamp": "2026-04-23T23:47:35.137995Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-04-23T23:47:35.138872Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-04-23T23:47:35.140724Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 7.7}
# {"timestamp": "2026-04-23T23:47:35.143076Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 9.97}
# {"timestamp": "2026-04-23T23:47:37.514206Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 51.42}
# {"timestamp": "2026-04-23T23:47:37.520510Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-04-23T23:47:37.969570Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.36}
# {"timestamp": "2026-04-23T23:47:48.260558Z", "level": "info", "event": "Getting model config for: gemm"}
# {"timestamp": "2026-04-23T23:47:48.267699Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-04-23T23:47:54.477315Z", "level": "warning", "event": "Could not determine if gemm is vision model: gemm is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`"}
# {"timestamp": "2026-04-23T23:47:54.750225Z", "level": "warning", "event": "Could not determine if gemm is embedding model: 401 Client Error. (Request ID: Root=1-69eaafaa-5b8b5f49465952f61abbfc1a;984681d8-e1a5-406a-befa-b6a95f2d3631)\n\nRepository Not Found for url: https://huggingface.co/api/models/gemm.\nPlease make sure you specified the correct `repo_id` and `repo_type`.\nIf you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication\nInvalid username or password."}
# {"timestamp": "2026-04-23T23:47:56.451771Z", "level": "warning", "event": "Could not determine if unsloth/gemm is vision model: unsloth/gemm is not a local folder and is not a valid model identifier listed on 'https://huggingface.co/models'\nIf this is a private repository, make sure to pass a token having permission to this repo either by logging in with `hf auth login` or by passing `token=<your_token>`"}
# {"timestamp": "2026-04-23T23:47:57.399574Z", "level": "info", "event": "Model config result for gemm: is_vision=False, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-04-23T23:47:57.631068Z", "level": "warning", "event": "Could not get model size for gemm: 401 Client Error. (Request ID: Root=1-69eaafad-5693b71040d3519b4ffab3cd;d3c5375b-821a-4eec-aec2-eb9e29ef74c8)\n\nRepository Not Found for url: https://huggingface.co/api/models/gemm.\nPlease make sure you specified the correct `repo_id` and `repo_type`.\nIf you are trying to access a private or gated repo, make sure you are authenticated. For more details, see https://huggingface.co/docs/huggingface_hub/authentication\nInvalid username or password."}
# {"timestamp": "2026-04-23T23:47:57.633557Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/gemm", "status_code": 200, "process_time_ms": 9374.86}
# {"timestamp": "2026-04-23T23:47:57.642227Z", "level": "info", "event": "Getting model config for: unsloth/gemma-4-E2B-it"}
# {"timestamp": "2026-04-23T23:47:57.650325Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E2B-it.yaml (via mapping)"}
# {"timestamp": "2026-04-23T23:47:57.651587Z", "level": "info", "event": "Model 'unsloth/gemma-4-E2B-it' needs transformers 5.x -- checking vision via subprocess"}
# {"timestamp": "2026-04-23T23:48:13.226595Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/gemma-4-E2B-it': model_type=gemma4, architectures=['Gemma4ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-04-23T23:48:14.697285Z", "level": "info", "event": "Model config result for unsloth/gemma-4-E2B-it: is_vision=True, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-04-23T23:48:14.945368Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/gemma-4-E2B-it", "status_code": 200, "process_time_ms": 17308.26}
# ={"timestamp": "2026-04-23T23:50:51.201049Z", "level": "info", "event": "Checking format for dataset: ahmedsamirio/oasst2-9k-translation"}
# {"timestamp": "2026-04-23T23:50:51.483343Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# README.md: 0.00B [00:00, ?B/s]
# {"timestamp": "2026-04-23T23:50:56.329305Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-04-23T23:50:56.332644Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 5135.33}
# {"timestamp": "2026-04-23T23:52:08.981453Z", "level": "info", "event": "Checking format for dataset: ahmedsamirio/oasst2-9k-translation"}
# {"timestamp": "2026-04-23T23:52:09.227239Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-04-23T23:52:11.650363Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-04-23T23:52:11.654833Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2675.55}
# {"timestamp": "2026-04-23T23:52:25.670302Z", "level": "info", "event": "Fetched dataset card: 874 chars, 0 metadata fields"}
# {"timestamp": "2026-04-23T23:52:25.675844Z", "level": "info", "event": "Loading advisor model: unsloth/gemma-4-E2B-it-GGUF (UD-Q4_K_XL)"}
# {"timestamp": "2026-04-23T23:52:26.150973Z", "level": "info", "event": "Resolving GGUF: unsloth/gemma-4-E2B-it-GGUF/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-04-23T23:52:26.387325Z", "level": "info", "event": "GGUF resolved from cache: /root/.cache/huggingface/hub/models--unsloth--gemma-4-E2B-it-GGUF/snapshots/f064409f340b34190993560b2168133e5dbae558/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-04-23T23:52:26.639274Z", "level": "info", "event": "GGUF metadata: context_length=131072"}
# {"timestamp": "2026-04-23T23:52:26.640014Z", "level": "info", "event": "GGUF metadata: chat_template=16317 chars"}
# {"timestamp": "2026-04-23T23:52:26.640686Z", "level": "info", "event": "GGUF metadata: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-04-23T23:52:26.642112Z", "level": "info", "event": "GGUF metadata: model supports tool calling"}
# {"timestamp": "2026-04-23T23:52:26.670807Z", "level": "info", "event": "GGUF size: 3.0 GB, est. KV cache: 0.1 GB, context: 2048, GPUs free: [(0, 14910)], selected: [0], fit: False"}
# {"timestamp": "2026-04-23T23:52:26.671559Z", "level": "info", "event": "Reasoning model: {'enable_thinking': True} by default"}
# {"timestamp": "2026-04-23T23:52:26.672031Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.cache/huggingface/hub/models--unsloth--gemma-4-E2B-it-GGUF/snapshots/f064409f340b34190993560b2168133e5dbae558/gemma-4-E2B-it-UD-Q4_K_XL.gguf --port 47905 -c 2048 --parallel 1 --flash-attn on --no-context-shift -ngl -1 --jinja --chat-template-kwargs {\"enable_thinking\": true}"}
# {"timestamp": "2026-04-23T23:52:30.251753Z", "level": "info", "event": "llama-server ready on port 47905 for model 'advisor:unsloth/gemma-4-E2B-it-GGUF:UD-Q4_K_XL'"}
# {"timestamp": "2026-04-23T23:52:30.252524Z", "level": "info", "event": "Advisor model loaded in 4.6s"}
# {"timestamp": "2026-04-23T23:52:30.503972Z", "level": "info", "event": "Pass 1: Classifying dataset..."}
# {"timestamp": "2026-04-23T23:52:30.505021Z", "level": "info", "event": "Advisor request: enable_thinking=False (per-request override)"}
# {"timestamp": "2026-04-23T23:52:32.240274Z", "level": "info", "event": "Pass 1 done (1.7s): {'dataset_type': 'translation', 'is_conversational': False, 'needs_conversion': True, 'description': 'This dataset consists of translated messages between English, Modern Standard Arabic, and Egyptian Arabic.', 'task_description': 'The task is to translate text from English to Modern Standard Arabic and Egyptian Arabic, or vice versa.'}"}
# {"timestamp": "2026-04-23T23:52:32.241102Z", "level": "info", "event": "Pass 2: Mapping columns to roles..."}
# {"timestamp": "2026-04-23T23:52:32.242836Z", "level": "info", "event": "Advisor request: enable_thinking=False (per-request override)"}
# {"timestamp": "2026-04-23T23:52:34.110402Z", "level": "info", "event": "Pass 2 done (1.9s): {'column_roles': {'en': 'user', 'ar': 'assistant', 'eg': 'assistant'}, 'label_mapping': None, 'notes': \"The 'en' column is assigned to 'user' as it represents the source text for translation. The 'ar' and 'eg' columns are assigned to 'assistant' as they represent the target translations that the model should learn to generate.\"}"}
# {"timestamp": "2026-04-23T23:52:34.111217Z", "level": "info", "event": "Pass 3: Generating system prompt..."}
# {"timestamp": "2026-04-23T23:52:34.112070Z", "level": "info", "event": "Advisor request: enable_thinking=False (per-request override)"}
# {"timestamp": "2026-04-23T23:52:34.933986Z", "level": "info", "event": "Pass 3 done (0.8s): You are a bilingual translator specializing in English to Modern Standard Arabic and Egyptian Arabic. Your task is to translate the provided English text into both Modern Standard Arabic and Egyptian "}
# {"timestamp": "2026-04-23T23:52:34.934736Z", "level": "info", "event": "Advisor complete (9.3s): type=translation, mapping={'en': 'user', 'ar': 'assistant', 'eg': 'assistant'}, sys_prompt=True, label_map=False"}
# {"timestamp": "2026-04-23T23:52:35.401877Z", "level": "info", "event": "Unloaded GGUF model: advisor:unsloth/gemma-4-E2B-it-GGUF:UD-Q4_K_XL"}
# {"timestamp": "2026-04-23T23:52:35.402876Z", "level": "info", "event": "Advisor model unloaded"}
# {"timestamp": "2026-04-23T23:52:35.403600Z", "level": "info", "event": "Conversion advisor succeeded: type=translation"}
# {"timestamp": "2026-04-23T23:52:35.406818Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/ai-assist-mapping", "status_code": 200, "process_time_ms": 10000.74}
# {"timestamp": "2026-04-23T23:52:44.419969Z", "level": "info", "event": "Checking format for dataset: ahmedsamirio/oasst2-9k-translation"}
# {"timestamp": "2026-04-23T23:52:44.682109Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-04-23T23:52:47.117271Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-04-23T23:52:47.121198Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2703.49}
# {"timestamp": "2026-04-23T23:52:47.528413Z", "level": "info", "event": "Starting training job with model: unsloth/gemma-4-E2B-it"}
# {"timestamp": "2026-04-23T23:52:47.534143Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E2B-it.yaml (via mapping)"}
# {"timestamp": "2026-04-23T23:52:47.535040Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-04-23T23:52:49.047516Z", "level": "warning", "event": "Could not load config for 'unsloth/gemma-4-E2B-it': The checkpoint you are trying to load has model type `gemma4` but Transformers does not recognize this architecture. This could be because of an issue with the checkpoint, or because your version of Transformers is out of date.\n\nYou can update Transformers with the command `pip install --upgrade transformers`. If this does not work, and the checkpoint is very new, then there may not be a release version that supports this model yet. In this case, you can get the most up-to-date code by installing Transformers from source with the command `pip install git+https://github.com/huggingface/transformers.git`"}
# {"timestamp": "2026-04-23T23:52:49.122099Z", "level": "info", "event": "Training subprocess started (pid=42647)"}
# {"timestamp": "2026-04-23T23:52:49.143112Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 1618.73}
# {"timestamp": "2026-04-23T23:52:50.550409Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 535.1}
# {"timestamp": "2026-04-23T23:52:50.552874Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 537.45}
# {"timestamp": "2026-04-23T23:52:51.469637Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.42}
# {"timestamp": "2026-04-23T23:52:51.475710Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 4.19}
# {"timestamp": "2026-04-23T23:52:52.851949Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 7.48}
# {"timestamp": "2026-04-23T23:52:52.966182Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.62}
# {"timestamp": "2026-04-23T23:52:52.987471Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 6.15}
# {"timestamp": "2026-04-23T23:52:54.477224Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.62}
# {"timestamp": "2026-04-23T23:52:54.484504Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 5.16}
# {"timestamp": "2026-04-23T23:52:55.971334Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.62}
# {"timestamp": "2026-04-23T23:52:55.978857Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 5.76}
# {"timestamp": "2026-04-23T23:52:57.475080Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 3.59}
# {"timestamp": "2026-04-23T23:52:57.483616Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.85}
# {"timestamp": "2026-04-23T23:52:58.976704Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.53}
# {"timestamp": "2026-04-23T23:52:58.983583Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.66}
# {"timestamp": "2026-04-23T23:53:00.477472Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 6.8}
# {"timestamp": "2026-04-23T23:53:00.487969Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 10.6}
# {"timestamp": "2026-04-23T23:53:01.981486Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 3.97}
# {"timestamp": "2026-04-23T23:53:01.988189Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3.16}
# {"timestamp": "2026-04-23T23:53:03.467509Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.38}
# {"timestamp": "2026-04-23T23:53:03.478607Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 6.06}
# {"timestamp": "2026-04-23T23:53:04.971348Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.62}
# {"timestamp": "2026-04-23T23:53:04.979120Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 3.76}
# {"timestamp": "2026-04-23T23:53:06.471902Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.76}
# {"timestamp": "2026-04-23T23:53:06.477841Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.57}
# {"timestamp": "2026-04-23T23:53:07.969185Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 3.74}
# {"timestamp": "2026-04-23T23:53:07.976366Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 3
MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)"}
# {"timestamp": "2026-04-24T00:01:02.228275Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 5.4}
# {"timestamp": "2026-04-24T00:01:30.912010Z", "level": "info", "event": "Checking format for dataset: ahmedsamirio/oasst2-9k-translation"}
# {"timestamp": "2026-04-24T00:01:31.200553Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-04-24T00:01:33.555051Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-04-24T00:01:33.564327Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2654.44}
# {"timestamp": "2026-04-24T00:01:33.999904Z", "level": "info", "event": "Starting training job with model: unsloth/gemma-4-E2B-it"}
# {"timestamp": "2026-04-24T00:01:34.010660Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E2B-it.yaml (via mapping)"}
# {"timestamp": "2026-04-24T00:01:35.482114Z", "level": "warning", "event": "Could not load config for 'unsloth/gemma-4-E2B-it': The checkpoint you are trying to load has model type `gemma4` but Transformers does not recognize this architecture. This could be because of an issue with the checkpoint, or because your version of Transformers is out of date.\n\nYou can update Transformers with the command `pip install --upgrade transformers`. If this does not work, and the checkpoint is very new, then there may not be a release version that supports this model yet. In this case, you can get the most up-to-date code by installing Transformers from source with the command `pip install git+https://github.com/huggingface/transformers.git`"}
# {"timestamp": "2026-04-24T00:01:35.522323Z", "level": "info", "event": "Training subprocess started (pid=45306)"}
# {"timestamp": "2026-04-24T00:01:35.537880Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 1540.06}
# {"timestamp": "2026-04-24T00:01:36.415150Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.71}
# {"timestamp": "2026-04-24T00:01:36.469470Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 3.5}
# {"timestamp": "2026-04-24T00:01:37.849584Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 2.15}
# {"timestamp": "2026-04-24T00:01:39.867550Z", "level": "info", "event": "Stop requested: save=False is_active=True"}
# {"timestamp": "2026-04-24T00:01:39.869568Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/stop", "status_code": 200, "process_time_ms": 8.39}
# {"timestamp": "2026-04-24T00:01:40.646476Z", "level": "info", "event": "Force-terminating subprocess for immediate reset (cancel path)"}
# {"timestamp": "2026-04-24T00:01:40.647608Z", "level": "info", "event": "Force-terminating training subprocess (pid=45306)"}
# {"timestamp": "2026-04-24T00:01:40.722334Z", "level": "info", "event": "Reset training state: clearing runtime + metric history"}
# {"timestamp": "2026-04-24T00:01:40.723387Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/reset", "status_code": 200, "process_time_ms": 78.22}
# {"timestamp": "2026-04-24T00:01:41.319166Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 3.11}
# {"timestamp": "2026-04-24T00:02:08.950291Z", "level": "info", "event": "Checking format for dataset: ahmedsamirio/oasst2-9k-translation"}
# {"timestamp": "2026-04-24T00:02:09.090239Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 5.28}
# {"timestamp": "2026-04-24T00:02:09.091541Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 5.73}
# {"timestamp": "2026-04-24T00:02:09.191590Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-04-24T00:02:11.406053Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-04-24T00:02:11.412901Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2465.19}
# {"timestamp": "2026-04-24T00:02:11.995130Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 422, "process_time_ms": 1.76}
# {"timestamp": "2026-04-24T00:02:12.595022Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 3.08}
# {"timestamp": "2026-04-24T00:02:27.068235Z", "level": "info", "event": "Checking format for dataset: ahmedsamirio/oasst2-9k-translation"}
# {"timestamp": "2026-04-24T00:02:27.189041Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 3.49}
# {"timestamp": "2026-04-24T00:02:27.190139Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.5}
# {"timestamp": "2026-04-24T00:02:27.326097Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-04-24T00:02:29.529950Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-04-24T00:02:29.535636Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2469.16}
# {"timestamp": "2026-04-24T00:02:29.927807Z", "level": "info", "event": "Starting training job with model: unsloth/gemma-4-E2B-it"}
# {"timestamp": "2026-04-24T00:02:29.933979Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E2B-it.yaml (via mapping)"}
# {"timestamp": "2026-04-24T00:02:31.420036Z", "level": "warning", "event": "Could not load config for 'unsloth/gemma-4-E2B-it': The checkpoint you are trying to load has model type `gemma4` but Transformers does not recognize this architecture. This could be because of an issue with the checkpoint, or because your version of Transformers is out of date.\n\nYou can update Transformers with the command `pip install --upgrade transformers`. If this does not work, and the checkpoint is very new, then there may not be a release version that supports this model yet. In this case, you can get the most up-to-date code by installing Transformers from source with the command `pip install git+https://github.com/huggingface/transformers.git`"}
# {"timestamp": "2026-04-24T00:02:31.464842Z", "level": "info", "event": "Training subprocess started (pid=45565)"}
# {"timestamp": "2026-04-24T00:02:31.482528Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 1556.26}
# {"timestamp": "2026-04-24T00:02:34.871938Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 7.35}
# {"timestamp": "2026-04-24T00:03:20.358000Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 3.37}
# {"timestamp": "2026-04-24T00:03:20.365215Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 4.02}
# {"timestamp": "2026-04-24T00:03:22.165745Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.75}
# {"timestamp": "2026-04-24T00:03:22.169490Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.02}
# {"timestamp": "2026-04-24T00:03:31.865593Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 2.53}
# {"timestamp": "2026-04-24T00:03:31.877653Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 2.3}
# ={"timestamp": "2026-04-24T00:06:11.478657Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/download-progress", "status_code": 200, "process_time_ms": 20.74}
# {"timestamp": "2026-04-24T00:06:11.507179Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/download-progress", "status_code": 200, "process_time_ms": 23.91}
# =

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
